# %%
from sklearn.datasets import make_regression
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
x,y = make_regression(n_samples=100, n_features=1, n_informative=1,n_targets=1,noise=40)

# %%
plt.scatter(x,y)

# %%
# first apply OLS for calculating intercept and coeficient 
lr = LinearRegression()

# %%
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([91.68385199])

# %%
lr.intercept_
# Out:
# 1.3415491537203366

# %%
# Now making my own calass and Method for fit and perdict

# %%
class GDREGRESSOR():
    
    def __init__(self,learning_rate,epochs):
        self.m=53.67017267
        self.b= 0   #taking it randomly
        self.epochs = epochs
        self.lr = learning_rate

    def fit(self,x,y): 
        #calculating b and m using GD
        for i in range(self.epochs):
            loss_slope_b = -2 * np.sum(y - self.m*x.ravel() - self.b)
            loss_slope_m = -2 * np.sum((y - self.m*x.ravel() - self.b)*x.ravel())
            self.b = self.b - (self.lr*loss_slope_b)
            self.m = self.m - (self.lr*loss_slope_m)
            #print(loss_slope,self.b)
        print(self.m,self.b)

    
    def predict(self,x):
        return self.m*x + self.b

# %%
GD=GDREGRESSOR(0.001,100)
GD.fit(x,y)   # the m and b value are near same as the value that we calcualte by using OLS method
# Out:
# 91.6838512174522 1.3415484187954472

# %%
GD.predict(x)
# Out:
# array([[-132.06411591],
#        [   5.02488605],
#        [  16.83562751],
#        [ -63.05906408],
#        [  21.25067387],
#        [  -8.03395143],
#        [-185.47449566],
#        [  98.63348431],
#        [ -74.10849904],
#        [ -39.19661966],
#        [   4.81543908],
#        [ -21.21645662],
#        [   0.38475608],
#        [ 149.95585714],
#        [ -13.72428449],
#        [ 115.98226045],
#        [  36.20478415],
#        [ -35.34987705],
#        [-105.39875239],
#        [  -7.35075377],
#        [  22.50246269],
#        [-134.92330227],
#        [ -40.21081851],
#        [  52.47997098],
#        [-160.79268594],
#        [  48.91871685],
#        [  77.57462418],
#        [ -86.45530668],
#        [ -86.52410665],
#        [  85.14711095],
#        [ -41.09226657],
#        [  94.3134717 ],
#        [   3.39363074],
#        [  39.83562584],
#        [  16.07597997],
#        [ -72.77973258],
#        [ -45.47807339],
#        [ 104.17250211],
# ...
