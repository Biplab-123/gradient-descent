# %%
# code will be divided into two part first portion will be just normal OLS then the actucal Stochastic GD also it is for dimension data(multiple input coloumn)
#creating class for sochastic, in this GD we chnage the step size for every row mean value of m and b will be calculte in every row and by this we can 
#convergence to the solution much faster than Batch GD as we will be need much less epochs values

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.datasets import load_diabetes
import time

# %%
x,y = load_diabetes(return_X_y=True)

# %%
print(x.shape)
print(y.shape)
# Out:
# (442, 10)
# (442,)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
LG=LinearRegression()
LG.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=LG.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# 0.4399338661568968

# %%
x_train.shape
# Out:
# (353, 10)

# %%
#creating My own class  for SGDREGRESSor for multiple input coloumn

# %%
class SGDREGRESSOR():
    def __init__(self,learning_rate=0.01,epochs=100):
        self.intercept_=None
        self.coef_=None
        self.lr=learning_rate
        self.epochs=epochs
        
    def fit(self,x_train,y_train):
        #intialize the coef_
        self.intercept_ = 0
        self.coef_ = np.ones(x_train.shape[1])

        for i in range(self.epochs):
            for j in range(x_train.shape[0]):  # as we take one row at a time to calculate the 
                idx=np.random.randint(0,x_train.shape[0])   # creating the random number(index number) for the row in which the iteration will happen
                y_hat = np.dot(x_train[idx],self.coef_) + self.intercept_

                #For updating the intercept value for each randomly selected row 
                intercept_der = -2 * (y_train[idx] - y_hat)  # calculating the derivative using -2*(yi - y^) this formula for a single row value
                self.intercept_ = self.intercept_ - (self.lr * intercept_der)

                #For updating the coeficient value for each randomly selected row 
                coef_der = -2 * np.dot((y_train[idx] - y_hat),x_train[idx])
                self.coef_ = self.coef_ - (self.lr * coef_der)
        print(self.intercept_ ,self.coef_)

    
    def predict(self,x_test):
        return np.dot(x_test,self.coef_) + self.intercept_ #y= mx+c for more than one number of coef and intercept

# %%
#creating object
sgd = SGDREGRESSOR(learning_rate=0.01,epochs=50)

# %%
start = time.time()
sgd.fit(x_train,y_train)
print("time taken to train",time.time() - start)
# Out:
# 148.4539558350272 [  49.95004701  -70.72907155  359.92002037  250.40659797   15.10014779
#   -32.65487148 -171.41017889  129.79307441  321.44434459  130.69796626]
# time taken to train 0.2923719882965088

# %%
y_pred = sgd.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# 0.42988755231543985

# %%
# the epochs requirement is less than the previous one , that mean it's faster than the batch GD
# the value of r2_score is change every time as the row value is random for the stochastic but it will remain close to the solution
